# %% [markdown]
# # AI 地图宣传视频生成器 — Colab 版
# 输入地名 → 自动获取地图 → 生成文化动画视频

# %%
# @title 1. 安装依赖
import os; os.chdir("/content")
# !rm -rf /content/C-VisualEngineer
# !git clone https://github.com/caixiaoyao-cxy/C-VisualEngineer.git
os.chdir("/content/C-VisualEngineer")
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118 -q
# !pip install diffusers transformers accelerate peft opencv-python-headless moviepy pillow numpy safetensors httpx parsel -q
# !python -c "import torch; print('CUDA:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO')"

# %%
# @title 2. 运行流水线（交互式）
# !python bridge.py

# %%
# @title 或者指定地名直接跑
# !python bridge.py --place 杭州

# %%
# @title 3. 下载视频
from google.colab import files
import os
if os.path.exists('output/video/final_video.mp4'):
    files.download('output/video/final_video.mp4')
else:
    print('视频还没生成，先跑上面的流水线')
