# %% [markdown]
# # 🗺️ AI 地图宣传视频生成器 — Colab 版
# ### 点 ▶ 运行即可，免费 T4 GPU

# %%
# @title 1. 检查 GPU
import torch
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"显存: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %%
# @title 2. 上传代码压缩包
from google.colab import files
import zipfile
import os

print("请上传 C-VisualEngineer 文件夹（选所有文件打包成 zip）")
print("在 Windows 上: 选中所有文件 → 右键 → 压缩到 ZIP")
uploaded = files.upload()

for name in uploaded:
    with zipfile.ZipFile(name, 'r') as z:
        z.extractall('/content/')
    print(f"解压完成: {name}")

# %cd /content/C-VisualEngineer
# !ls -la

# %%
# @title 3. 安装依赖
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118 -q
# !pip install diffusers transformers accelerate peft opencv-python-headless moviepy pillow numpy safetensors -q
print('✅ 依赖安装完成')

# %%
# @title 4. 跑测试（不用地图图片）
# !python gen_test_contours.py
# !bash run_pipeline.sh storyboard_example.json

# %%
# @title 5. 下载视频
from google.colab import files
files.download('output/video/final_video.mp4')
