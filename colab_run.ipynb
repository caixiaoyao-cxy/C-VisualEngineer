# %% [markdown]
# # 文化手账视频生成器
# 逐单元格运行即可。

# %%
# Cell 1: 克隆仓库 + 安装依赖 + 中文字体
# !git clone https://github.com/caixiaoyao-cxy/C-VisualEngineer.git /content/C-VisualEngineer 2>/dev/null || echo "已存在"
# %cd /content/C-VisualEngineer
# !git pull origin master
# !apt-get install -y fonts-noto-cjk fonts-wqy-microhei 2>/dev/null | tail -2
# !pip install -q fastmcp opencv-python numpy pydantic httpx Pillow dashscope tavily

# %%
# Cell 2: 设置 API Key（改你自己的）
import os
os.environ["DASHSCOPE_API_KEY"] = "sk-你的dashscope-key"
os.environ["SEARCH_API_KEY"] = "tvly-你的tavily-key"
os.environ["ALIBABA_API_KEY"] = os.environ["DASHSCOPE_API_KEY"]
os.environ["SEARCH_PROVIDER"] = "tavily"
print("API key 已设置")

# %%
# Cell 3: 运行（修改地名即可）
# !python multi_agent_video.py "Hangzhou"
